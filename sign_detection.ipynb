# %% [markdown]
# Getting hand landmarks

# %%
import mediapipe as mp
import cv2
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np
import os

# %% [markdown]
# Load Dataset

# %%
images_info = []

train_path = "./dataset/"

for class_name in os.listdir(train_path):
    for image_name in os.listdir(train_path + class_name):
        images_info.append({
            'class': class_name,
            'path': './dataset/' + class_name + '/' + image_name
        })
        
print(images_info)
# Out:
# [{'class': 'A', 'path': './dataset/A/10014_A.jpg'}, {'class': 'A', 'path': './dataset/A/10021_A.jpg'}, {'class': 'A', 'path': './dataset/A/10023_A.jpg'}, {'class': 'A', 'path': './dataset/A/10050_A.jpg'}, {'class': 'A', 'path': './dataset/A/10056_A.jpg'}, {'class': 'A', 'path': './dataset/A/10058_A.jpg'}, {'class': 'A', 'path': './dataset/A/10070_A.jpg'}, {'class': 'A', 'path': './dataset/A/10072_A.jpg'}, {'class': 'A', 'path': './dataset/A/10099_A.jpg'}, {'class': 'A', 'path': './dataset/A/10111_A.jpg'}, {'class': 'A', 'path': './dataset/A/10187_A.jpg'}, {'class': 'A', 'path': './dataset/A/10201_A.jpg'}, {'class': 'A', 'path': './dataset/A/10203_A.jpg'}, {'class': 'A', 'path': './dataset/A/10235_A.jpg'}, {'class': 'A', 'path': './dataset/A/10244_A.jpg'}, {'class': 'A', 'path': './dataset/A/10290_A.jpg'}, {'class': 'A', 'path': './dataset/A/10313_A.jpg'}, {'class': 'A', 'path': './dataset/A/10337_A.jpg'}, {'class': 'A', 'path': './dataset/A/10412_A.jpg'}, {'class': 'A', 'path': './dataset/A/10490_A.jpg'}, {'class': 'A', 'path': './dataset/A/10499_A.jpg'}, {'class': 'A', 'path': './dataset/A/10511_A.jpg'}, {'class': 'A', 'path': './dataset/A/10579_A.jpg'}, {'class': 'A', 'path': './dataset/A/10618_A.jpg'}, {'class': 'A', 'path': './dataset/A/10629_A.jpg'}, {'class': 'A', 'path': './dataset/A/10639_A.jpg'}, {'class': 'A', 'path': './dataset/A/10640_A.jpg'}, {'class': 'A', 'path': './dataset/A/10661_A.jpg'}, {'class': 'A', 'path': './dataset/A/1066_A.jpg'}, {'class': 'A', 'path': './dataset/A/10687_A.jpg'}, {'class': 'A', 'path': './dataset/A/10713_A.jpg'}, {'class': 'A', 'path': './dataset/A/10732_A.jpg'}, {'class': 'A', 'path': './dataset/A/10752_A.jpg'}, {'class': 'A', 'path': './dataset/A/10776_A.jpg'}, {'class': 'A', 'path': './dataset/A/10822_A.jpg'}, {'class': 'A', 'path': './dataset/A/10848_A.jpg'}, {'class': 'A', 'path': './dataset/A/10868_A.jpg'}, {'class': 'A', 'path': './dataset/A/1086_A.jpg'}, {'class': 'A', 'path': './dataset/A/10874_A.jpg'}, {'class': 'A', 'path': './dataset/A/10881_A.jpg'}, {'class': 'A', 'path': './dataset/A/10887_A.jpg'}, {'class': 'A', 'path': './dataset/A/10890_A.jpg'}, {'class': 'A', 'path': './dataset/A/10912_A.jpg'}, {'class': 'A', 'path': './dataset/A/10928_A.jpg'}, {'class': 'A', 'path': './dataset/A/10929_A.jpg'}, {'class': 'A', 'path': './dataset/A/11027_A.jpg'}, {'class': 'A', 'path': './dataset/A/11057_A.jpg'}, {'class': 'A', 'path': './dataset/A/11097_A.jpg'}, {'class': 'A', 'path': './dataset/A/11142_A.jpg'}, {'class': 'A', 'path': './dataset/A/11162_A.jpg'}, {'class': 'A', 'path': './dataset/A/11173_A.jpg'}, {'class': 'A', 'path': './dataset/A/11208_A.jpg'}, {'class': 'A', 'path': './dataset/A/11230_A.jpg'}, {'class': 'A', 'path': './dataset/A/1125_A.jpg'}, {'class': 'A', 'path': './dataset/A/11272_A.jpg'}, {'class': 'A', 'path': './dataset/A/11319_A.jpg'}, {'class': 'A', 'path': './dataset/A/11339_A.jpg'}, {'class': 'A', 'path': './dataset/A/11346_A.jpg'}, {'class': 'A', 'path': './dataset/A/11347_A.jpg'}, {'class': 'A', 'path': './dataset/A/11362_A.jpg'}, {'class': 'A', 'path': './dataset/A/11367_A.jpg'}, {'class': 'A', 'path': './dataset/A/11382_A.jpg'}, {'class': 'A', 'path': './dataset/A/11388_A.jpg'}, {'class': 'A', 'path': './dataset/A/11406_A.jpg'}, {'class': 'A', 'path': './dataset/A/11413_A.jpg'}, {'class': 'A', 'path': './dataset/A/11429_A.jpg'}, {'class': 'A', 'path': './dataset/A/11447_A.jpg'}, {'class': 'A', 'path': './dataset/A/11458_A.jpg'}, {'class': 'A', 'path': './dataset/A/11460_A.jpg'}, {'class': 'A', 'path': './dataset/A/11470_A.jpg'}, {'class': 'A', 'path': './dataset/A/11487_A.jpg'}, {'class': 'A', 'path': './dataset/A/11521_A.jpg'}, {'class': 'A', 'path': './dataset/A/11550_A.jpg'}, {'class': 'A', 'path': './dataset/A/11557_A.jpg'}, {'class': 'A', 'path': './dataset/A/11614_A.jpg'}, {'class': 'A', 'path': './dataset/A/11616_A.jpg'}, {'class': 'A', 'path': './dataset/A/11714_A.jpg'}, {'class': 'A', 'path': './dataset/A/11740_A.jpg'}, {'class': 'A', 'path': ' ...

# %%
model_path = "D:\BINUS\Assignments\Semester 3\AI\SignoAI\hand_landmarker.task"

# %%
MARGIN = 10  # pixels
FONT_SIZE = 1
FONT_THICKNESS = 1
HANDEDNESS_TEXT_COLOR = (88, 205, 54) # vibrant green

def draw_landmarks_on_image(rgb_image, detection_result):
    hand_landmarks_list = detection_result.hand_landmarks
    handedness_list = detection_result.handedness
    annotated_image = np.copy(rgb_image)

    # Loop through the detected hands to visualize
    for idx in range(len(hand_landmarks_list)):
        hand_landmarks = hand_landmarks_list[idx]
        handedness = handedness_list[idx]

        # Draw the hand landmarks.
        hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        hand_landmarks_proto.landmark.extend([
        landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks
        ])
        solutions.drawing_utils.draw_landmarks(
        annotated_image,
        hand_landmarks_proto,
        solutions.hands.HAND_CONNECTIONS,
        solutions.drawing_styles.get_default_hand_landmarks_style(),
        solutions.drawing_styles.get_default_hand_connections_style())

        # Get the top left corner of the detected hand's bounding box.
        height, width, _ = annotated_image.shape
        x_coordinates = [landmark.x for landmark in hand_landmarks]
        y_coordinates = [landmark.y for landmark in hand_landmarks]
        print(f"x_coordinates: {x_coordinates[0]}, y_coordinates: {y_coordinates[0]}")
        text_x = int(min(x_coordinates) * width)
        text_y = int(min(y_coordinates) * height) - MARGIN

        # Draw handedness (left or right hand) on the image.
        cv2.putText(annotated_image, f"{handedness[0].category_name}",
                    (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                    FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)

    return annotated_image

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 2: Create an HandLandmarker object.
base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options,
                                       num_hands=2)
detector = vision.HandLandmarker.create_from_options(options)

# %%
for idx, image_info in enumerate(images_info):
    # STEP 3: Load the input image.
    # image = mp.Image.create_from_file(image_info['path'])
    
    bgr_image = cv2.imread(image_info['path'])
    rgb_image = cv2.cvtColor(bgr_image, cv2.COLOR_BGR2RGB)
    image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_image)
    
    # STEP 4: Detect hand landmarks from the input image.
    detection_result = detector.detect(image)
    print(detection_result)

    # STEP 5: Process the classification result. In this case, visualize it.
    annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
    cv2.imshow("Result", cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    if(idx == 2):
        break
# Out:
# HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])

# %% [markdown]
# Pre process to get the relations to each other

# %% [markdown]
# Saving to CSV file
